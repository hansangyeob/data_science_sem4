# %%
# import libraries
import pandas as pd
import numpy as np

# %%
# string
my_string = 'Don\'t mess with ' + "me. \n New line"
print(my_string)
# Out:
# Don't mess with me.
#  New line

# %%
a = 1
c = "two"
str(a) + c
# Out:
# '1two'

# %%
# list
num_list = [1,2,3,4,5,6]
print(num_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
type(num_list)
# Out:
# list

# %%
import numpy as np
# array
num_array = np.array(num_list)
print(num_array)
# Out:
# [1 2 3 4 5 6]

# %%
type(num_array)
# Out:
# numpy.ndarray

# %%
# array shape
num_array.shape
# Out:
# (6,)

# %%
# reshape array to 2d matrix
num_array = num_array.reshape(2,3)

# %%
num_array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
num_array.shape
# Out:
# (2, 3)

# %%
# dict
num_dict = {1: "one", 2: "two"}

# %%
num_dict
# Out:
# {1: 'one', 2: 'two'}

# %%
type(num_dict)
# Out:
# dict

# %%
# loop through dict
for key in num_dict:
    print(key)
    print(num_dict[key])
# Out:
# 1
# one
# 2
# two

# %%
# loop through list
for i in num_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
# loop through array
for i in num_array:
    print(i)
# Out:
# [1 2 3]
# [4 5 6]

# %%
# convert to pandas dataframes
import pandas as pd
df_array = pd.DataFrame(num_array, columns=['A1', 'A2', 'A3'])
df_array
# Out:
#    A1  A2  A3
# 0   1   2   3
# 1   4   5   6

# %%
# convert back to numpy array
array = np.array(df_array)
array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
# abalone dataset
abalone_p = "abalone.data.csv"

# %%
abalone = pd.read_csv(abalone_p, sep=',', decimal='.',header=None, 
                      names=['Sex', 'Length', 'Diameter', 'Height', 
                             'Whole weight', 'Shucked weight', 'Viscera weight', 
                             'Shell weight', 'Rings'])

# %%
# check types of all columns
abalone.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
# print out df
abalone
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
# pandas series
Y = abalone["Rings"]

# %%
print(type(Y))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# subset by col
X = abalone[["Height","Rings"]]

# %%
num_array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
X.shape
# Out:
# (4177, 2)

# %%
# subset by row
df_subset = abalone[abalone["Rings"]>9]

# %%
df_subset
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 6      F   0.530     0.415   0.150        0.7775          0.2370
# 7      F   0.545     0.425   0.125        0.7680          0.2940
# 9      F   0.550     0.440   0.150        0.8945          0.3145
# ...   ..     ...       ...     ...           ...             ...
# 4170   M   0.550     0.430   0.130        0.8395          0.3155
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 3             0.1140        0.1550     10
# 6             0.1415        0.3300     20
# ...

# %%
len(df_subset)
# Out:
# 3916

# %%
# loop through pandas using range number:
for i in range(len(abalone)):
   # print(abalone.iloc[i,3:])
     print(abalone.loc[i,["Sex","Height"]])
# Out:
# Sex           M
# Height    0.095
# Name: 0, dtype: object
# Sex          M
# Height    0.09
# Name: 1, dtype: object
# Sex           F
# Height    0.135
# Name: 2, dtype: object
# Sex           M
# Height    0.125
# Name: 3, dtype: object
# Sex          I
# Height    0.08
# Name: 4, dtype: object
# Sex           I
# Height    0.095
# Name: 5, dtype: object
# Sex          F
# Height    0.15
# Name: 6, dtype: object
# Sex           F
# Height    0.125
# Name: 7, dtype: object
# Sex           M
# Height    0.125
# Name: 8, dtype: object
# Sex          F
# Height    0.15
# Name: 9, dtype: object
# Sex          F
# Height    0.14
# Name: 10, dtype: object
# Sex          M
# Height    0.11
# Name: 11, dtype: object
# Sex           M
# Height    0.135
# Name: 12, dtype: object
# Sex           F
# Height    0.145
# Name: 13, dtype: object
# Sex         F
# Height    0.1
# Name: 14, dtype: object
# Sex          M
# Height    0.13
# Name: 15, dtype: object
# Sex           I
# Height    0.085
# ...

# %%
# loop through pandas using rows
for row in df_subset.iterrows():
    print(row[1]["Height"])
# Out:
# 0.095
# 0.125
# 0.15
# 0.125
# 0.15
# 0.14
# 0.11
# 0.135
# 0.145
# 0.1
# 0.13
# 0.1
# 0.095
# 0.1
# 0.155
# 0.165
# 0.14
# 0.185
# 0.14
# 0.18
# 0.14
# 0.165
# 0.165
# 0.165
# 0.175
# 0.2
# 0.155
# 0.135
# 0.135
# 0.13
# 0.12
# 0.13
# 0.16
# 0.185
# 0.12
# 0.13
# 0.17
# 0.175
# 0.195
# 0.15
# 0.15
# 0.14
# 0.17
# 0.175
# 0.165
# 0.16
# 0.14
# 0.18
# 0.14
# 0.16
# 0.16
# 0.135
# 0.15
# 0.175
# 0.165
# 0.19
# 0.195
# 0.125
# 0.145
# 0.16
# 0.14
# 0.16
# 0.155
# 0.165
# 0.125
# 0.125
# 0.115
# 0.135
# 0.105
# 0.14
# 0.16
# 0.165
# 0.165
# 0.155
# 0.145
# 0.19
# 0.155
# 0.13
# 0.125
# 0.12
# 0.145
# 0.19
# 0.16
# 0.135
# 0.13
# 0.19
# 0.215
# 0.17
# 0.165
# 0.165
# 0.16
# 0.175
# 0.21
# 0.23
# 0.19
# 0.175
# 0.205
# 0.22
# 0.175
# 0.215
# 0.15
# 0.18
# 0.175
# 0.16
# 0.175
# 0.2
# 0.19
# 0.15
# 0.185
# 0.16
# 0.18
# 0.17
# 0.15
# 0.14
# 0.155
# 0.15
# 0.185
# 0.16
# 0.185
# 0.165
# 0.145
# 0.17
# 0.17
# 0.145
# 0.105
# 0.16
# 0.14
# 0.135
# 0.145
# 0.15
# 0.105
# 0.165
# 0.16
# 0.135
# ...

# %%
# reset index and drop index column
df_reset = df_subset.reset_index(drop=True)

# %%
df_reset
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.440     0.365   0.125        0.5160          0.2155
# 2      F   0.530     0.415   0.150        0.7775          0.2370
# 3      F   0.545     0.425   0.125        0.7680          0.2940
# 4      F   0.550     0.440   0.150        0.8945          0.3145
# ...   ..     ...       ...     ...           ...             ...
# 2076   M   0.550     0.430   0.130        0.8395          0.3155
# 2077   F   0.565     0.450   0.165        0.8870          0.3700
# 2078   M   0.590     0.440   0.135        0.9660          0.4390
# 2079   F   0.625     0.485   0.150        1.0945          0.5310
# 2080   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.1140        0.1550     10
# 2             0.1415        0.3300     20
# ...

# %%
# fake dataset
fake_abalone = abalone.copy()

# %%
# check value count
fake_abalone['Sex'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
fake_abalone.Rings.isin([9,10,15])
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 4172    False
# 4173     True
# 4174     True
# 4175     True
# 4176    False
# Name: Rings, Length: 4177, dtype: bool

# %%
# fake_abalone.loc[fake_abalone["Rings"].isin([1, 2, 9]), 'Height'] = 'I  '
fake_abalone.loc[fake_abalone.Rings.isin([1, 2, 9]), 'Height'] = 'I  '
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-964a754dc833> in <module>
#       1 # fake_abalone.loc[fake_abalone["Rings"].isin([1, 2, 9]), 'Height'] = 'I  '
# ----> 2 fake_abalone.loc[fake_abalone.Rings.isin([1, 2, 9]), 'Height'] = 'I  '
#
# NameError: name 'fake_abalone' is not defined

# %%
# check value count
fake_abalone['Height'].value_counts()
# Out:
# I        691
# 0.15     204
# 0.175    180
# 0.155    172
# 0.14     166
# 0.165    161
# 0.16     149
# 0.125    147
# 0.145    145
# 0.135    143
# 0.1      134
# 0.12     133
# 0.17     130
# 0.13     129
# 0.115    116
# 0.11     115
# 0.09     113
# 0.18     112
# 0.185     98
# 0.19      91
# 0.105     89
# 0.095     82
# 0.085     71
# 0.195     70
# 0.08      69
# 0.2       62
# 0.075     58
# 0.07      47
# 0.205     40
# 0.065     39
# 0.215     30
# 0.06      26
# 0.055     25
# 0.21      22
# 0.05      18
# 0.22      17
# 0.04      13
# 0.225     13
# 0.045     11
# 0.23      10
# 0.035      6
# 0.235      6
# 0.03       6
# 0.24       4
# 0.025      4
# 0.25       3
# 0.0        2
# 0.02       2
# 0.015      1
# 0.515      1
# 1.13       1
# Name: Height, dtype: int64

# %%
# strip white spaces
fake_abalone["Sex"] = fake_abalone["Sex"].str.strip()

# %%
fake_abalone.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
# check value again
fake_abalone['Sex'].value_counts()
# Out:
# M    1525
# I    1345
# F    1307
# Name: Sex, dtype: int64

# %%
def my_function():

# apply lambda function method
    fake_abalone["Sex"] = fake_abalone["Sex"].apply(lambda x: x.strip().replace("I", "II"))

# %%
# check na
fake_abalone.isna().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
# check basic stats
fake_abalone.describe()
# Out:
#             Length     Diameter  Whole weight  Shucked weight  Viscera weight  \
# count  4177.000000  4177.000000   4177.000000     4177.000000     4177.000000
# mean      0.523992     0.407881      0.828742        0.359367        0.180594
# std       0.120093     0.099240      0.490389        0.221963        0.109614
# min       0.075000     0.055000      0.002000        0.001000        0.000500
# 25%       0.450000     0.350000      0.441500        0.186000        0.093500
# 50%       0.545000     0.425000      0.799500        0.336000        0.171000
# 75%       0.615000     0.480000      1.153000        0.502000        0.253000
# max       0.815000     0.650000      2.825500        1.488000        0.760000
#
#        Shell weight        Rings
# count   4177.000000  4177.000000
# mean       0.238831     9.933684
# std        0.139203     3.224169
# min        0.001500     1.000000
# 25%        0.130000     8.000000
# 50%        0.234000     9.000000
# ...

# %%
# plot scatter matrix
from pandas.plotting import scatter_matrix
scatter_matrix(abalone,alpha=0.2,figsize=(16,16),diagonal='hist')
# Out:
# array([[<AxesSubplot:xlabel='Length', ylabel='Length'>,
#         <AxesSubplot:xlabel='Diameter', ylabel='Length'>,
#         <AxesSubplot:xlabel='Height', ylabel='Length'>,
#         <AxesSubplot:xlabel='Whole weight', ylabel='Length'>,
#         <AxesSubplot:xlabel='Shucked weight', ylabel='Length'>,
#         <AxesSubplot:xlabel='Viscera weight', ylabel='Length'>,
#         <AxesSubplot:xlabel='Shell weight', ylabel='Length'>,
#         <AxesSubplot:xlabel='Rings', ylabel='Length'>],
#        [<AxesSubplot:xlabel='Length', ylabel='Diameter'>,
#         <AxesSubplot:xlabel='Diameter', ylabel='Diameter'>,
#         <AxesSubplot:xlabel='Height', ylabel='Diameter'>,
#         <AxesSubplot:xlabel='Whole weight', ylabel='Diameter'>,
#         <AxesSubplot:xlabel='Shucked weight', ylabel='Diameter'>,
#         <AxesSubplot:xlabel='Viscera weight', ylabel='Diameter'>,
#         <AxesSubplot:xlabel='Shell weight', ylabel='Diameter'>,
# ...
